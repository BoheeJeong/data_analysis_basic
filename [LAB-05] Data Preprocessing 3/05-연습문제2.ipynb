# %% [markdown]
# # LAB 05 - Data preprocessing 3
#
# ## 02 데이터 재구조화

# %% [markdown]
# 📘 연습문제 — 게임 토너먼트 최고 득점자를 찾아라!
#
# game_scores 데이터셋은 최근 열린 게임 토너먼트의 경기 결과 데이터입니다.
#
# 데이터는 선수 이름(player) 과 각 스테이지(stage1, stage2, stage3) 점수로 구성되어 있습니다.
#
# 일부 선수는 특정 스테이지에 참여하지 않아 점수가 비어 있을 수 있습니다.
#
# 모든 스테이지에 참여한 선수들 중에서, 평균 점수가 가장 높은 **“최고의 선수”**를 찾아내고,
# 그 선수의 평균 점수를 계산하세요.
#
# ✔️ 요구사항
# 1. 각 스테이지 점수가 열로 구성된 데이터를,
# 선수와 스테이지 레벨에 따른 점수를 나타내는 형태로 재구조화하세요.
#
# 즉, wide → long 형태로 변환하여
# player, stage, score 구조로 만드세요.
#
# 2. 스테이지에 모두 참여한 선수만 대상으로 분석하세요.
#
# (→ 결측치가 없는 선수만 남기기)
#
# 3. 선수별 평균 점수를 계산하세요.

# %%
#패키지 참조
from hossam import load_data
from pandas import DataFrame

# %%
game_scores = load_data('game_scores')
game_scores
# Out:
# [data] https://data.hossam.kr/data/lab05/game_scores.xlsx
# [desc] 최근 열린 게임 토너먼트 경기 결과 데이터 (인덱스와 메타데이터 없음)
# [!] Cannot read metadata
#     player  stage1  stage2  stage3
# 0    Alice      85    92.0    88.0
# 1      Bob      78     NaN    95.0
# 2  Charlie      90    88.0    91.0
# 3    David      82    85.0     NaN
# 4      Eva      95    98.0    99.0

# %%
# ✔️ 요구사항
# 1. 각 스테이지 점수가 열로 구성된 데이터를,
# 선수와 스테이지 레벨에 따른 점수를 나타내는 형태로 재구조화하세요.

# 즉, wide → long 형태로 변환하여
# player, stage, score 구조로 만드세요.

# 2. 스테이지에 모두 참여한 선수만 대상으로 분석하세요.

# (→ 결측치가 없는 선수만 남기기)

# 3. 선수별 평균 점수를 계산하세요.

game_scores_copy = game_scores.copy()

game_scores_copy2=game_scores_copy.set_index('player')
game_scores_copy2
# Out:
#          stage1  stage2  stage3
# player
# Alice        85    92.0    88.0
# Bob          78     NaN    95.0
# Charlie      90    88.0    91.0
# David        82    85.0     NaN
# Eva          95    98.0    99.0

# %%
#결측치가 있는 선수 행 지우기
game_scores_copy3=game_scores_copy2.copy()
game_scores_copy4=game_scores_copy3.dropna()
game_scores_copy4
# Out:
#          stage1  stage2  stage3
# player
# Alice        85    92.0    88.0
# Charlie      90    88.0    91.0
# Eva          95    98.0    99.0

# %%
#결측치가 없는 선수들에 대해서 stack
df = DataFrame(game_scores_copy4.stack())
df
# Out:
#                    0
# player
# Alice   stage1  85.0
#         stage2  92.0
#         stage3  88.0
# Charlie stage1  90.0
#         stage2  88.0
#         stage3  91.0
# Eva     stage1  95.0
#         stage2  98.0
#         stage3  99.0

# %%
game_scores_copy4.unstack()
game_scores_copy4
# Out:
#          stage1  stage2  stage3
# player
# Alice        85    92.0    88.0
# Charlie      90    88.0    91.0
# Eva          95    98.0    99.0

# %%
df3=DataFrame(game_scores_copy4.mean(axis=1))
df3
# Out:
#                  0
# player
# Alice    88.333333
# Charlie  89.666667
# Eva      97.333333
